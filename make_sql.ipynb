# %%
import pandas as pd 
import numpy as np
import sqlalchemy
import psycopg2

# %%
config = 'postgresql://postgres:password@localhost:5432/jp_lit'

sqlalchemy.create_engine(config)
# Out:
# Engine(postgresql://postgres:***@localhost:5432/jp_lit)

# %%
df = pd.read_csv('./data/list_person_all_extended_utf8.csv', usecols=['作品ID', '作品名', '人物ID', 'XHTML/HTMLファイルURL'])

df
# Out:
#         作品ID             作品名  人物ID  \
# 0      59898     ウェストミンスター寺院  1257
# 1      56078            駅伝馬車  1257
# 2      60224             駅馬車  1257
# 3      60225          寡婦とその子  1257
# 4      60231           クリスマス  1257
# ...      ...             ...   ...
# 19374  55622               夢  1395
# 19375  49876  『劉生画集及芸術観』について  1395
# 19376  49913          霊的本能主義  1395
# 19377  49914        露伴先生の思い出  1395
# 19378  45210         純粋経済学要論  1185
#
#                                        XHTML/HTMLファイルURL
# 0      https://www.aozora.gr.jp/cards/001257/files/59...
# 1      https://www.aozora.gr.jp/cards/001257/files/56...
# 2      https://www.aozora.gr.jp/cards/001257/files/60...
# 3      https://www.aozora.gr.jp/cards/001257/files/60...
# 4      https://www.aozora.gr.jp/cards/001257/files/60...
# ...                                                  ...
# 19374  https://www.aozora.gr.jp/cards/001395/files/55...
# 19375  https://www.aozora.gr.jp/cards/001395/files/49...
# ...

# %%
df.shape
# Out:
# (19379, 4)

# %%
books = pd.read_csv('./bookinfo.csv', index_col=0, names=[None, '作品ID', 'inception', 'char_count', 'text'])

books.shape
# Out:
# (19163, 4)

# %%
nulls(df)
# Out:
#                  col  null_count  % null
# 0               作品ID           0    0.00
# 1                作品名           0    0.00
# 2               人物ID           0    0.00
# 3  XHTML/HTMLファイルURL         217    1.12

# %%
books = books.sort_index()

# %%
books
# Out:
#         作品ID inception  char_count  \
# 0      59898       NaN     10562.0
# 1      56078       NaN      6041.0
# 2      60224       NaN      6216.0
# 3      60225       NaN      7042.0
# 4      60231       NaN      4953.0
# ...      ...       ...         ...
# 19157  55622      1952     12400.0
# 19158  49876      1921      4655.0
# 19159  49913      1907     12075.0
# 19160  49914      1947      4146.0
# 19161  45210       NaN     86962.0
#
#                                                     text
# 0      深いおどろきにうたれて、名高いウェストミンスターに真鍮や石の記念碑となってすべての王侯貴族が...
# 1      いざ、これより樂しまむ、仕置を受くる憂なく、遊びたのしむ時ぞ來ぬ、時ぞ來ぬれば、いちはやく、...
# 2      すべてよし。何して遊ぼと叱られない。時はきた。さっさと本など投げだそう。――休日に歌った昔の...
# 3      年老いた人をいたわりなさい。その銀髪は、名誉と尊敬をつねに集めてきたのです。――マーロウ作「...
# 4      だが、あのなつかしい、思い出ふかいクリスマスのお爺さんはもう逝ってしまったのだろうか。あとに...
# ...                                                  ...
# 19157  夢の話をするのはあまり気のきいたことではない。確か痴人夢を説くという言葉があったはずだ。そう...
# 19158  自分は現代の画家中に岸田君ほど明らかな「成長」を示している人を知らない。誇張でなく岸田君は一...
# ...

# %%
df
# Out:
#         作品ID             作品名  人物ID  \
# 0      59898     ウェストミンスター寺院  1257
# 1      56078            駅伝馬車  1257
# 2      60224             駅馬車  1257
# 3      60225          寡婦とその子  1257
# 4      60231           クリスマス  1257
# ...      ...             ...   ...
# 19374  55622               夢  1395
# 19375  49876  『劉生画集及芸術観』について  1395
# 19376  49913          霊的本能主義  1395
# 19377  49914        露伴先生の思い出  1395
# 19378  45210         純粋経済学要論  1185
#
#                                        XHTML/HTMLファイルURL
# 0      https://www.aozora.gr.jp/cards/001257/files/59...
# 1      https://www.aozora.gr.jp/cards/001257/files/56...
# 2      https://www.aozora.gr.jp/cards/001257/files/60...
# 3      https://www.aozora.gr.jp/cards/001257/files/60...
# 4      https://www.aozora.gr.jp/cards/001257/files/60...
# ...                                                  ...
# 19374  https://www.aozora.gr.jp/cards/001395/files/55...
# 19375  https://www.aozora.gr.jp/cards/001395/files/49...
# ...

# %%
def nulls(df):
    return pd.DataFrame({
    'col': df.columns,
    'null_count': df.isna().sum(),
    '% null': np.round(df.isna().sum()  * 100 / len(df), 2)
    }).reset_index(drop=True)

# %%
df = df.dropna(axis=0)

# %%
nulls(df)
# Out:
#                  col  null_count  % null
# 0               作品ID           0     0.0
# 1                作品名           0     0.0
# 2               人物ID           0     0.0
# 3  XHTML/HTMLファイルURL           0     0.0

# %%
df.duplicated(subset=['作品ID']).value_counts()
# Out:
# False    17628
# True      1534
# Name: count, dtype: int64

# %%
df[df.duplicated(subset='作品ID')]
# Out:
#         作品ID         作品名  人物ID  \
# 521    57321  朝に想い、夜に省みる  1843
# 641     1128  「ケルトの薄明」より  1085
# 645       44        春の心臓  1085
# 802    50328       相対性理論  1429
# 1039   50768        麻を刈る   886
# ...      ...         ...   ...
# 19207  62688          ワル  2265
# 19221  51287      怪談牡丹灯籠  1501
# 19304   2223          絵姿    20
# 19323  44722       兵士と女優  1203
# 19378  45210     純粋経済学要論  1185
#
#                                        XHTML/HTMLファイルURL
# 521    https://www.aozora.gr.jp/cards/001842/files/57...
# 641    https://www.aozora.gr.jp/cards/001085/files/11...
# 645    https://www.aozora.gr.jp/cards/001085/files/44...
# 802    https://www.aozora.gr.jp/cards/001428/files/50...
# 1039   https://www.aozora.gr.jp/cards/000050/files/50...
# ...                                                  ...
# 19207  https://www.aozora.gr.jp/cards/002265/files/62...
# 19221  https://www.aozora.gr.jp/cards/001501/files/51...
# 19304  https://www.aozora.gr.jp/cards/000020/files/22...
# ...

# %%
books.duplicated(subset='作品ID').value_counts()
# Out:
# False    17628
# True      1535
# Name: count, dtype: int64

# %%
books.drop_duplicates(inplace=True, keep='first')

# %%
books
# Out:
#         作品ID inception  char_count  \
# 0      59898       NaN     10562.0
# 1      56078       NaN      6041.0
# 2      60224       NaN      6216.0
# 3      60225       NaN      7042.0
# 4      60231       NaN      4953.0
# ...      ...       ...         ...
# 19156  49911      1935      4761.0
# 19157  55622      1952     12400.0
# 19158  49876      1921      4655.0
# 19159  49913      1907     12075.0
# 19160  49914      1947      4146.0
#
#                                                     text
# 0      深いおどろきにうたれて、名高いウェストミンスターに真鍮や石の記念碑となってすべての王侯貴族が...
# 1      いざ、これより樂しまむ、仕置を受くる憂なく、遊びたのしむ時ぞ來ぬ、時ぞ來ぬれば、いちはやく、...
# 2      すべてよし。何して遊ぼと叱られない。時はきた。さっさと本など投げだそう。――休日に歌った昔の...
# 3      年老いた人をいたわりなさい。その銀髪は、名誉と尊敬をつねに集めてきたのです。――マーロウ作「...
# 4      だが、あのなつかしい、思い出ふかいクリスマスのお爺さんはもう逝ってしまったのだろうか。あとに...
# ...                                                  ...
# 19156  問題にしない時にはわかり切ったことと思われているものが、さて問題にしてみると実にわからなくな...
# 19157  夢の話をするのはあまり気のきいたことではない。確か痴人夢を説くという言葉があったはずだ。そう...
# ...

# %%
df.drop_duplicates(subset='作品ID', inplace=True, keep='first')
# Out:
# C:\Users\Jaden\AppData\Local\Temp\ipykernel_7724\2210062776.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(subset='作品ID', inplace=True, keep='first')

# %%
df.duplicated().value_counts()
# Out:
# False    17628
# Name: count, dtype: int64

# %%
books.duplicated().value_counts()
# Out:
# False    17628
# Name: count, dtype: int64

# %%
df['作品ID'].describe()
# Out:
# count    17628.000000
# mean     37731.215283
# std      21935.396649
# min          2.000000
# 25%       4870.750000
# 50%      47041.500000
# 75%      53992.250000
# max      62694.000000
# Name: 作品ID, dtype: float64

# %%
books['作品ID'].describe()
# Out:
# count    17628.000000
# mean     37731.215283
# std      21935.396649
# min          2.000000
# 25%       4870.750000
# 50%      47041.500000
# 75%      53992.250000
# max      62694.000000
# Name: 作品ID, dtype: float64

# %%
works = pd.merge(df, books, how='inner', on='作品ID', )

# %%
nulls(works)
# Out:
#                  col  null_count  % null
# 0               作品ID           0    0.00
# 1                作品名           0    0.00
# 2               人物ID           0    0.00
# 3  XHTML/HTMLファイルURL           0    0.00
# 4          inception        7830   44.42
# 5         char_count         277    1.57
# 6               text         277    1.57

# %%
works.head()
# Out:
#     作品ID          作品名  人物ID  \
# 0  59898  ウェストミンスター寺院  1257
# 1  56078         駅伝馬車  1257
# 2  60224          駅馬車  1257
# 3  60225       寡婦とその子  1257
# 4  60231        クリスマス  1257
#
#                                    XHTML/HTMLファイルURL inception  char_count  \
# 0  https://www.aozora.gr.jp/cards/001257/files/59...       NaN     10562.0
# 1  https://www.aozora.gr.jp/cards/001257/files/56...       NaN      6041.0
# 2  https://www.aozora.gr.jp/cards/001257/files/60...       NaN      6216.0
# 3  https://www.aozora.gr.jp/cards/001257/files/60...       NaN      7042.0
# 4  https://www.aozora.gr.jp/cards/001257/files/60...       NaN      4953.0
#
#                                                 text
# 0  深いおどろきにうたれて、名高いウェストミンスターに真鍮や石の記念碑となってすべての王侯貴族が...
# 1  いざ、これより樂しまむ、仕置を受くる憂なく、遊びたのしむ時ぞ來ぬ、時ぞ來ぬれば、いちはやく、...
# 2  すべてよし。何して遊ぼと叱られない。時はきた。さっさと本など投げだそう。――休日に歌った昔の...
# 3  年老いた人をいたわりなさい。その銀髪は、名誉と尊敬をつねに集めてきたのです。――マーロウ作「...
# 4  だが、あのなつかしい、思い出ふかいクリスマスのお爺さんはもう逝ってしまったのだろうか。あとに...

# %%
diff_URLS = works[works['text'].isnull()]

# %%
diff_URLS[diff_URLS['XHTML/HTMLファイルURL'].str.contains('https://www.aozora.gr.jp/cards')][['作品ID', 'XHTML/HTMLファイルURL']].to_csv('newbatch.csv', index=True, encoding='UTF-8')

# %%
newbatch = pd.read_csv('new.csv', index_col=0, names=[None, '作品ID', 'inception', 'char_count', 'text'] )

newbatch
# Out:
#        作品ID  inception  char_count  \
# 1312    733        NaN       68547
# 1579   1255        NaN       80656
# 2081   1273        NaN      114145
# 2092    911        NaN        3147
# 2231   3213        NaN       13304
# ...     ...        ...         ...
# 17528  2203        NaN        4245
# 17531  2205        NaN        1970
# 17534  2202        NaN        1323
# 17536  2201        NaN         593
# 17544  2207        NaN        1076
#
#                                                     text
# 1312   神秘的半獸主義岩野泡鳴入力者注目次はしがき（一）緒言（二）メーテルリンクの神秘説（三）エメル...
# 1579   海野十三敗戦日記海野十三空襲都日記（一）はしがき二週間ほど前より、帝都もかねて覚悟していたと...
# 2081   自叙伝大杉栄自叙伝（一）一赤旗事件でやられて、東京監獄から千葉監獄へ連れて行かれた、二日目か...
# 2092   遺言大杉栄四五年前の二月頃だった。或日、突然、明治大学の学生から電話がかかつて来て、今大学の...
# 2231   詩集＜色ガラスの街＞尾形亀之助此の一巻を父と母とに捧ぐ序の一りんてん機とアルコポン×りんてん...
# ...                                                  ...
# 17528  たべものの木若山牧水私は寢上戸（ねじやうご）とかいふ方で、酒に醉ふと直ぐ眠つてしまふ。いまの...
# 17531  庭さきの森の春若山牧水濱へ出る漁師たちの徑に沿うたわたしの庭の垣根は、もと此處が桃畑であつた...
# ...

# %%
nulls(newbatch)
# Out:
#           col  null_count  % null
# 0        作品ID           0    0.00
# 1   inception         126   90.65
# 2  char_count           0    0.00
# 3        text           0    0.00

# %%
idx = newbatch.index

idx
# Out:
# Index([ 1312,  1579,  2081,  2092,  2231,  2317,  3352,  3354,  3355,  3357,
#        ...
#        17469, 17471, 17472, 17478, 17484, 17528, 17531, 17534, 17536, 17544],
#       dtype='int64', length=139)

# %%
works.loc[idx,['inception', 'char_count', 'text']] = newbatch.loc[idx, ['inception', 'char_count', 'text']]

# %%
nulls(works)
# Out:
#                  col  null_count  % null
# 0               作品ID           0    0.00
# 1                作品名           0    0.00
# 2               人物ID           0    0.00
# 3  XHTML/HTMLファイルURL           0    0.00
# 4          inception        7817   44.34
# 5         char_count         138    0.78
# 6               text         138    0.78

# %%
idx = works[works['text'].isnull()].index

# %%
works = works.drop(index=idx)

# %%
nulls(works)
# Out:
#                  col  null_count  % null
# 0               作品ID           0    0.00
# 1                作品名           0    0.00
# 2               人物ID           0    0.00
# 3  XHTML/HTMLファイルURL           0    0.00
# 4          inception        7679   43.91
# 5         char_count           0    0.00
# 6               text           0    0.00

# %%
works.to_csv('books_final.csv', index=False, encoding='utf-8', header=True)

# %%
books[books.duplicated()].sort_values(by='作品ID')
# Out:
#         作品ID inception  char_count  \
# 14092      5       NaN      9029.0
# 10397      8       NaN     23066.0
# 641       44      1914      4690.0
# 17340    193      1914      6183.0
# 17486    193      1914      6183.0
# ...      ...       ...         ...
# 1987   62693       NaN      8016.0
# 2026   62694       NaN      2990.0
# 1563   62694       NaN      2990.0
# 14006  62694       NaN      2990.0
# 1562   62694       NaN      2990.0
#
#                                                     text
# 14092  このあいびきは先年仏蘭西で死去した、露国では有名な小説家、ツルゲーネフという人の端物の作です...
# 10397  友人シャーロック・ホームズを、昨年の秋、とある日に訪ねたことがあった。すると、ホームズは初老...
# 641    一人の老人が瞑想に耽りながら、岩の多い岸に坐つてゐる。顔には鳥の脚のやうに肉がない。処はジル...
# 17340  ブレドガアデで午食をして来た帰道である。牧師をしてゐる兄と己とである。兄はユウトランドで富饒...
# 17486  ブレドガアデで午食をして来た帰道である。牧師をしてゐる兄と己とである。兄はユウトランドで富饒...
# ...                                                  ...
# 1987   「かわいそう、あたしのお花がかれちゃってる！」っていったのは、イーダちゃんって子。「ゆうべは...
# 2026   時は春、日は朝、朝は七時、片岡に露みちて、揚雲雀なのりいで、蝸牛枝に這ひ、神、そらに知ろしめ...
# ...

# %%
nulls(books)
# Out:
#           col  null_count  % null
# 0        作品ID           0    0.00
# 1   inception        8934   46.62
# 2  char_count         357    1.86
# 3        text         357    1.86

# %%
books
# Out:
#       作品ID inception  char_count  \
# 505    208       NaN      8853.0
# 506    203       NaN      6071.0
# 507  50502       NaN      2707.0
# 508  50010      1923     13439.0
# 509   4993      1914      8594.0
# ..     ...       ...         ...
# 500    211      1920      6313.0
# 501    210      1922      5090.0
# 502    207      1910      3662.0
# 503  56503      1916     12599.0
# 504  61237      1917     12243.0
#
#                                                   text
# 505  Ａ兄近来出遇わなかったひどい寒さもやわらぎはじめたので、兄の蟄伏期も長いことなく終わるだろう...
# 506  「僕の帽子はおとうさんが東京から買って来て下さったのです。ねだんは二円八十銭で、かっこうもい...
# 507  私は前後約十二年北海道で過した。しかも私の生活としては一番大事と思われる時期を、最初の時は十...
# 508  たうとう勃凸は四年を終へない中に中学を退学した。退学させられた。学校といふものが彼にはさつぱ...
# 509  北の国も真夏のころは花よめのようなよそおいをこらして、大地は喜びに満ち、小川は走り、牧場の花...
# ..                                                 ...
# 500  一僕は小さい時に絵を描くことが好きでした。僕の通っていた学校は横浜の山の手という所にありまし...
# 501  私が正月号の改造に発表した「宣言一つ」について、広津和郎氏が時事紙上に意見を発表された。それ...
# 502  一二つの道がある。一つは赤く、一つは青い。すべての人がいろいろの仕方でその上を歩いている。あ...
# ...

# %%
books['author_id'] = df.人物ID

# %%
books.sort_index().loc[3024]
# Out:
# 作品ID                                                      51583
# inception                                                  1940
# char_count                                               3774.0
# text          おどろき池の中には、黄色なすいれんが咲いていました。金魚の赤い姿が、水の上に浮いたりまるい葉...
# author_id                                                1475.0
# Name: 3024, dtype: object

# %%
df[df['作品ID'] == 51583].head(10)
# Out:
#        作品ID     作品名  人物ID                                  XHTML/HTMLファイルURL
# 3054  51583  少年の日二景  1475  https://www.aozora.gr.jp/cards/001475/files/51...

# %%
books = books.sort_index()

# %%
df['XHTML/HTMLファイルURL']
# Out:
# 0        https://www.aozora.gr.jp/cards/001257/files/59...
# 1        https://www.aozora.gr.jp/cards/001257/files/56...
# 2        https://www.aozora.gr.jp/cards/001257/files/60...
# 3        https://www.aozora.gr.jp/cards/001257/files/60...
# 4        https://www.aozora.gr.jp/cards/001257/files/60...
#                                ...
# 19374    https://www.aozora.gr.jp/cards/001395/files/55...
# 19375    https://www.aozora.gr.jp/cards/001395/files/49...
# 19376    https://www.aozora.gr.jp/cards/001395/files/49...
# 19377    https://www.aozora.gr.jp/cards/001395/files/49...
# 19378    https://www.aozora.gr.jp/cards/001185/files/45...
# Name: XHTML/HTMLファイルURL, Length: 19162, dtype: object

# %%
books['url'] = df['XHTML/HTMLファイルURL']

# %%
nulls(df)
# Out:
#                  col  null_count  % null
# 0               作品ID           0     0.0
# 1                作品名           0     0.0
# 2               人物ID           0     0.0
# 3  XHTML/HTMLファイルURL           0     0.0

# %%
nulls(books)
# Out:
#           col  null_count  % null
# 0        作品ID           0    0.00
# 1   inception        7830   44.42
# 2  char_count         277    1.57
# 3        text         277    1.57

# %%
works = pd.merge(df, books, how='left', on='作品ID')

# %%
nulls = pd.DataFrame({
    'col': works.columns,
    'null_count': works.isna().sum(),
    '% null': np.round(works.isna().sum()  * 100 / len(works), 2)
}).reset_index(drop=True)

nulls
# Out:
#                  col  null_count  % null
# 0               作品ID           0    0.00
# 1                作品名           0    0.00
# 2               人物ID           0    0.00
# 3  XHTML/HTMLファイルURL           0    0.00
# 4          inception       11373   50.47
# 5         char_count         520    2.31
# 6               text         520    2.31

# %%
works.head()
# Out:
#     作品ID          作品名  人物ID  \
# 0  59898  ウェストミンスター寺院  1257
# 1  59898  ウェストミンスター寺院  1257
# 2  56078         駅伝馬車  1257
# 3  56078         駅伝馬車  1257
# 4  60224          駅馬車  1257
#
#                                    XHTML/HTMLファイルURL inception  char_count  \
# 0  https://www.aozora.gr.jp/cards/001257/files/59...       NaN     10562.0
# 1  https://www.aozora.gr.jp/cards/001257/files/59...       NaN     10562.0
# 2  https://www.aozora.gr.jp/cards/001257/files/56...       NaN      6041.0
# 3  https://www.aozora.gr.jp/cards/001257/files/56...       NaN      6041.0
# 4  https://www.aozora.gr.jp/cards/001257/files/60...       NaN      6216.0
#
#                                                 text
# 0  深いおどろきにうたれて、名高いウェストミンスターに真鍮や石の記念碑となってすべての王侯貴族が...
# 1  深いおどろきにうたれて、名高いウェストミンスターに真鍮や石の記念碑となってすべての王侯貴族が...
# 2  いざ、これより樂しまむ、仕置を受くる憂なく、遊びたのしむ時ぞ來ぬ、時ぞ來ぬれば、いちはやく、...
# 3  いざ、これより樂しまむ、仕置を受くる憂なく、遊びたのしむ時ぞ來ぬ、時ぞ來ぬれば、いちはやく、...
# 4  すべてよし。何して遊ぼと叱られない。時はきた。さっさと本など投げだそう。――休日に歌った昔の...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19162 entries, 0 to 19378
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   作品ID               19162 non-null  int64
#  1   作品名                19162 non-null  object
#  2   人物ID               19162 non-null  int64
#  3   XHTML/HTMLファイルURL  19162 non-null  object
# dtypes: int64(2), object(2)
# memory usage: 748.5+ KB

# %%
np.unique(df['XHTML/HTMLファイルURL'])
# Out:
# array(['http://akirahp.s199.coreserver.jp/Gen1-2.html',
#        'http://akirahp.s199.coreserver.jp/Orion1-6.html',
#        'http://akirahp.s199.coreserver.jp/novel_TFG.html', ...,
#        'https://www.aozora.gr.jp/cards/002265/files/62686_78161.html',
#        'https://www.aozora.gr.jp/cards/002265/files/62687_78202.html',
#        'https://www.aozora.gr.jp/cards/002265/files/62688_78208.html'],
#       shape=(17619,), dtype=object)

# %%
nulls = pd.DataFrame({
    'col': df.columns,
    'null_count': df.isna().sum(),
    '% null': np.round(df.isna().sum()  * 100 / len(df), 2)
}).reset_index(drop=True)

nulls
# Out:
#                  col  null_count  % null
# 0               作品ID           0     0.0
# 1                作品名           0     0.0
# 2               人物ID           0     0.0
# 3  XHTML/HTMLファイルURL           0     0.0

# %%
df[df['XHTML/HTMLファイルURL'].str.contains('https://www.aozora.gr.jp/cards')].count() / len(df)
# Out:
# 作品ID                 0.988936
# 作品名                  0.988936
# 人物ID                 0.988936
# XHTML/HTMLファイルURL    0.988936
# dtype: float64

# %%
df.head(10)
# Out:
#     作品ID          作品名  人物ID                                  XHTML/HTMLファイルURL
# 0  59898  ウェストミンスター寺院  1257  https://www.aozora.gr.jp/cards/001257/files/59...
# 1  56078         駅伝馬車  1257  https://www.aozora.gr.jp/cards/001257/files/56...
# 2  60224          駅馬車  1257  https://www.aozora.gr.jp/cards/001257/files/60...
# 3  60225       寡婦とその子  1257  https://www.aozora.gr.jp/cards/001257/files/60...
# 4  60231        クリスマス  1257  https://www.aozora.gr.jp/cards/001257/files/60...
# 5  56033    クリスマス・イーヴ  1257  https://www.aozora.gr.jp/cards/001257/files/56...
# 6  60232    クリスマス・イーヴ  1257  https://www.aozora.gr.jp/cards/001257/files/60...
# 7  60226           傷心  1257  https://www.aozora.gr.jp/cards/001257/files/60...
# 8  60233       ジョン・ブル  1257  https://www.aozora.gr.jp/cards/001257/files/60...
# 9  60357          新浦島  1257  https://www.aozora.gr.jp/cards/001257/files/60...

# %%
len('底本:「スケッチ・ブック」岩波文庫、岩波書店 1935（昭和10）年9月15日第1刷発行2010（平成22）年2月23日第31刷発行※「並樹道」と「並樹路」の混在は底本通りです。入力：雀校正：小林繁雄2013年7月1日作成青空文庫作成ファイル：このファイルは、インターネットの図書館、青空文庫（http://www.aozora.gr.jp/）で作られました。入力、校正、制作にあたったのは、ボランティアの皆さんです。')
# Out:
# 209

# %%
df.to_csv('get_books.csv', encoding='UTF-8', index=False)

# %%
df = pd.read_excel('./data/aozora.xlsx', 'persons')

df
# Out:
#       人物ID                 姓名              姓           名        生年月日  \
# 0      148               夏目漱石             夏目          漱石  1867-02-09
# 1       81               宮沢賢治             宮沢          賢治  1896-08-27
# 2       35                太宰治             太宰           治  1909-06-19
# 3      119                中島敦             中島           敦  1909-05-05
# 4       96               夢野久作             夢野          久作  1889-01-04
# ...    ...                ...            ...         ...         ...
# 1099  1239           ラングアンドルー            ラング       アンドルー  1844-03-31
# 1100  1688  リヴィングストン・ジュニアヘンリー  リヴィングストン・ジュニア        ヘンリー  1748-10-13
# 1101   339            ルターマルチン            ルター        マルチン  1483-11-10
# 1102    29          レイモンドエリック          レイモンド        エリック         NaN
# 1103  1859   レ・ファニュジョゼフ・シェリダン         レ・ファニュ  ジョゼフ・シェリダン  1814-08-28
#
#             没年月日
# 0     1916-12-09
# 1     1933-09-21
# 2     1948-06-13
# 3     1942-12-04
# 4     1936-03-11
# ...          ...
# ...

# %%
df_append = pd.read_csv('author_with_first_pub_age.csv', usecols=['id', 'author', 'birthDate', 'deathDate', 'gender','birthPlace','religion', 'age_at_first_publication'])

df_append
# Out:
#         id author             birthDate             deathDate gender  \
# 0      148   夏目漱石  1867-02-09T00:00:00Z  1916-12-09T00:00:00Z     男性
# 1       81   宮沢賢治  1896-08-27T00:00:00Z  1933-09-21T00:00:00Z     男性
# 2       35    太宰治  1909-06-19T00:00:00Z  1948-06-13T00:00:00Z     男性
# 3      119    中島敦  1909-05-05T00:00:00Z  1942-12-04T00:00:00Z     男性
# 4       96   夢野久作  1889-01-04T00:00:00Z  1936-03-11T00:00:00Z     男性
# ...    ...    ...                   ...                   ...    ...
# 1099  1239    NaN                   NaN                   NaN    NaN
# 1100  1688    NaN                   NaN                   NaN    NaN
# 1101   339    NaN                   NaN                   NaN    NaN
# 1102    29    NaN                   NaN                   NaN    NaN
# 1103  1859    NaN                   NaN                   NaN    NaN
#
#      birthPlace religion  age_at_first_publication
# 0          喜久井町      NaN                      38.0
# ...

# %%
def nulls(df: pd.DataFrame):
    return pd.DataFrame({
        'cols': df.columns,
        "null_count": df.isna().sum().values,
        '% null': np.round(df.isna().sum().values / len(df) * 100, 3)
    }).sort_values(by='null_count', ascending=False).reset_index(drop=True)

# %%
df_append_na = nulls(df_append)

df_append_na
# Out:
#                        cols  null_count  % null
# 0                  religion        1081  97.917
# 1  age_at_first_publication        1004  90.942
# 2                birthPlace         615  55.707
# 3                 deathDate         499  45.199
# 4                    gender         476  43.116
# 5                 birthDate         472  42.754
# 6                    author         468  42.391
# 7                        id           0   0.000

# %%
df_append = df_append.dropna(axis=0, subset=['author'])

df_append = df_append.drop(columns=['religion', 'age_at_first_publication'])

# %%
df_append
# Out:
#         id author             birthDate             deathDate gender  \
# 0      148   夏目漱石  1867-02-09T00:00:00Z  1916-12-09T00:00:00Z     男性
# 1       81   宮沢賢治  1896-08-27T00:00:00Z  1933-09-21T00:00:00Z     男性
# 2       35    太宰治  1909-06-19T00:00:00Z  1948-06-13T00:00:00Z     男性
# 3      119    中島敦  1909-05-05T00:00:00Z  1942-12-04T00:00:00Z     男性
# 4       96   夢野久作  1889-01-04T00:00:00Z  1936-03-11T00:00:00Z     男性
# ...    ...    ...                   ...                   ...    ...
# 1086  1976   三木露風  1889-06-23T00:00:00Z  1964-12-29T00:00:00Z     男性
# 1087  1997  三岸好太郎  1903-04-18T00:00:00Z  1934-07-01T00:00:00Z     男性
# 1089  1740   宮川典子  1979-04-05T00:00:00Z  2019-09-12T00:00:00Z     女性
# 1091  1992    森律子  1890-10-30T00:00:00Z  1961-07-22T00:00:00Z     女性
# 1096  2013  吉岡禅寺洞  1889-07-02T00:00:00Z  1961-03-17T00:00:00Z     男性
#
#      birthPlace
# 0          喜久井町
# 1         花巻川口町
# 2           金木町
# 3           四谷区
# 4           福岡市
# ...         ...
# ...

# %%
df_append_na = nulls(df_append)

df_append_na
# Out:
#          cols  null_count  % null
# 0  birthPlace         147  23.113
# 1   deathDate          31   4.874
# 2      gender           8   1.258
# 3   birthDate           4   0.629
# 4      author           0   0.000
# 5          id           0   0.000

# %%
df_na = nulls(df)

df_na
# Out:
#    cols  null_count  % null
# 0  没年月日          96   8.696
# 1  生年月日          67   6.069
# 2     名          28   2.536
# 3  人物ID           0   0.000
# 4    姓名           0   0.000
# 5     姓           0   0.000

# %%
df = df.drop(columns=['姓', '名'])

# %%
df = df.rename({'姓名': 'author', '生年月日': 'birthDate', '没年月日': 'deathDate', '人物ID': 'id'},axis=1)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1104 entries, 0 to 1103
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         1104 non-null   int64
#  1   author     1104 non-null   object
#  2   birthDate  1037 non-null   object
#  3   deathDate  1008 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 34.6+ KB

# %%
df_na = nulls(df)

df_na
# Out:
#         cols  null_count  % null
# 0  deathDate          96   8.696
# 1  birthDate          67   6.069
# 2     author           0   0.000
# 3         id           0   0.000

# %%
df_append = df_append.drop(columns='author')

# %%
df_combine = pd.merge(df, df_append, on='id', how='left')

# %%
df_combine
# Out:
#         id             author birthDate_x deathDate_x           birthDate_y  \
# 0      148               夏目漱石  1867-02-09  1916-12-09  1867-02-09T00:00:00Z
# 1       81               宮沢賢治  1896-08-27  1933-09-21  1896-08-27T00:00:00Z
# 2       35                太宰治  1909-06-19  1948-06-13  1909-06-19T00:00:00Z
# 3      119                中島敦  1909-05-05  1942-12-04  1909-05-05T00:00:00Z
# 4       96               夢野久作  1889-01-04  1936-03-11  1889-01-04T00:00:00Z
# ...    ...                ...         ...         ...                   ...
# 1099  1239           ラングアンドルー  1844-03-31  1912-07-20                   NaN
# 1100  1688  リヴィングストン・ジュニアヘンリー  1748-10-13  1828-02-29                   NaN
# 1101   339            ルターマルチン  1483-11-10  1546-02-18                   NaN
# 1102    29          レイモンドエリック         NaN         NaN                   NaN
# 1103  1859   レ・ファニュジョゼフ・シェリダン  1814-08-28  1873-02-07                   NaN
#
#                deathDate_y gender birthPlace
# ...

# %%
df_na = nulls(df_combine)

df_na
# Out:
#           cols  null_count  % null
# 0   birthPlace         615  55.707
# 1  deathDate_y         499  45.199
# 2       gender         476  43.116
# 3  birthDate_y         472  42.754
# 4  deathDate_x          96   8.696
# 5  birthDate_x          67   6.069
# 6           id           0   0.000
# 7       author           0   0.000

# %%
idx = df_combine['deathDate_x'].isna()

# %%
idx
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1099    False
# 1100    False
# 1101    False
# 1102     True
# 1103    False
# Name: deathDate_x, Length: 1104, dtype: bool

# %%
added = df_combine[idx]['deathDate_y'].dropna()

# %%
added
# Out:
# 47      0800-01-01T00:00:00Z
# 672     1060-01-01T00:00:00Z
# 822     2002-10-01T00:00:00Z
# 980     2016-01-23T00:00:00Z
# 999     2006-02-28T00:00:00Z
# 1015    2022-03-07T00:00:00Z
# 1020    2022-09-08T00:00:00Z
# 1089    2019-09-12T00:00:00Z
# Name: deathDate_y, dtype: object

# %%
added = added.apply(lambda x: x[0:x.index(':') - 3])

added
# Out:
# 47      0800-01-01
# 672     1060-01-01
# 822     2002-10-01
# 980     2016-01-23
# 999     2006-02-28
# 1015    2022-03-07
# 1020    2022-09-08
# 1089    2019-09-12
# Name: deathDate_y, dtype: object

# %%
i = added.index

# %%
added = added.values

# %%
added
# Out:
# array(['0800-01-01', '1060-01-01', '2002-10-01', '2016-01-23',
#        '2006-02-28', '2022-03-07', '2022-09-08', '2019-09-12'],
#       dtype=object)

# %%
df_combine.loc[i, 'deathDate_x'] = added

# %%
df_combine.iloc[i]
# Out:
#         id author birthDate_x deathDate_x           birthDate_y  \
# 47    1519   稗田阿礼         NaN  0800-01-01  0700-01-01T00:00:00Z
# 672    133  菅原孝標女  1008-00-00  1060-01-01  1008-01-01T00:00:00Z
# 822   1886   藤井英男         NaN  2002-10-01  1913-03-20T00:00:00Z
# 980   1955   太田健一         NaN  2016-01-23  1936-02-15T00:00:00Z
# 999    122   桑原一世         NaN  2006-02-28  1946-02-01T00:00:00Z
# 1015    84   清水哲男  1938-02-15  2022-03-07  1938-01-01T00:00:00Z
# 1020    92  鈴木志郎康  1935-05-19  2022-09-08  1935-05-19T00:00:00Z
# 1089  1740   宮川典子         NaN  2019-09-12  1979-04-05T00:00:00Z
#
#                deathDate_y                                             gender  \
# 47    0800-01-01T00:00:00Z  http://www.wikidata.org/.well-known/genid/4e15...
# 672   1060-01-01T00:00:00Z                                                 女性
# 822   2002-10-01T00:00:00Z                                                 男性
# ...

# %%
df_combine.head()
# Out:
#     id author birthDate_x deathDate_x           birthDate_y  \
# 0  148   夏目漱石  1867-02-09  1916-12-09  1867-02-09T00:00:00Z
# 1   81   宮沢賢治  1896-08-27  1933-09-21  1896-08-27T00:00:00Z
# 2   35    太宰治  1909-06-19  1948-06-13  1909-06-19T00:00:00Z
# 3  119    中島敦  1909-05-05  1942-12-04  1909-05-05T00:00:00Z
# 4   96   夢野久作  1889-01-04  1936-03-11  1889-01-04T00:00:00Z
#
#             deathDate_y gender birthPlace
# 0  1916-12-09T00:00:00Z     男性       喜久井町
# 1  1933-09-21T00:00:00Z     男性      花巻川口町
# 2  1948-06-13T00:00:00Z     男性        金木町
# 3  1942-12-04T00:00:00Z     男性        四谷区
# 4  1936-03-11T00:00:00Z     男性        福岡市

# %%
idx = df_combine['birthDate_x'].isna()

added = df_combine[idx]['birthDate_y'].dropna()

# %%
added
# Out:
# 46      http://www.wikidata.org/.well-known/genid/ab88...
# 47                                   0700-01-01T00:00:00Z
# 800                                  1951-01-01T00:00:00Z
# 822                                  1913-03-20T00:00:00Z
# 953                                  1964-03-13T00:00:00Z
# 961                                  1960-03-08T00:00:00Z
# 975                                  1962-01-01T00:00:00Z
# 980                                  1936-02-15T00:00:00Z
# 999                                  1946-02-01T00:00:00Z
# 1002                                 1961-04-04T00:00:00Z
# 1018                                 1968-04-03T00:00:00Z
# 1089                                 1979-04-05T00:00:00Z
# Name: birthDate_y, dtype: object

# %%
added.loc[46] = None

# %%
added = added.dropna()

# %%
added
# Out:
# 47      0700-01-01T00:00:00Z
# 800     1951-01-01T00:00:00Z
# 822     1913-03-20T00:00:00Z
# 953     1964-03-13T00:00:00Z
# 961     1960-03-08T00:00:00Z
# 975     1962-01-01T00:00:00Z
# 980     1936-02-15T00:00:00Z
# 999     1946-02-01T00:00:00Z
# 1002    1961-04-04T00:00:00Z
# 1018    1968-04-03T00:00:00Z
# 1089    1979-04-05T00:00:00Z
# Name: birthDate_y, dtype: object

# %%
added = added.apply(lambda x: x[0: x.index(":") -3 ])
added
# Out:
# 47      0700-01-01
# 800     1951-01-01
# 822     1913-03-20
# 953     1964-03-13
# 961     1960-03-08
# 975     1962-01-01
# 980     1936-02-15
# 999     1946-02-01
# 1002    1961-04-04
# 1018    1968-04-03
# 1089    1979-04-05
# Name: birthDate_y, dtype: object

# %%
i, added = added.index, added.values

# %%
df_combine.loc[i, 'birthDate_x'] = added

# %%
df_combine.loc[i]
# Out:
#         id author birthDate_x deathDate_x           birthDate_y  \
# 47    1519   稗田阿礼  0700-01-01  0800-01-01  0700-01-01T00:00:00Z
# 800   1412   林田清明  1951-01-01         NaN  1951-01-01T00:00:00Z
# 822   1886   藤井英男  1913-03-20  2002-10-01  1913-03-20T00:00:00Z
# 953     30   山形浩生  1964-03-13         NaN  1964-03-13T00:00:00Z
# 961    100  山本ゆうじ  1960-03-08         NaN  1960-03-08T00:00:00Z
# 975     32   植松真人  1962-01-01         NaN  1962-01-01T00:00:00Z
# 980   1955   太田健一  1936-02-15  2016-01-23  1936-02-15T00:00:00Z
# 999    122   桑原一世  1946-02-01  2006-02-28  1946-02-01T00:00:00Z
# 1002    16   小中千昭  1961-04-04         NaN  1961-04-04T00:00:00Z
# 1018    21   白田秀彰  1968-04-03         NaN  1968-04-03T00:00:00Z
# 1089  1740   宮川典子  1979-04-05  2019-09-12  1979-04-05T00:00:00Z
#
#                deathDate_y                                             gender  \
# 47    0800-01-01T00:00:00Z  http://www.wikidata.org/.well-known/genid/4e15...
# ...

# %%
df_combine = df_combine.drop(columns=['birthDate_y', 'deathDate_y'])

df_combine
# Out:
#         id             author birthDate_x deathDate_x gender birthPlace
# 0      148               夏目漱石  1867-02-09  1916-12-09     男性       喜久井町
# 1       81               宮沢賢治  1896-08-27  1933-09-21     男性      花巻川口町
# 2       35                太宰治  1909-06-19  1948-06-13     男性        金木町
# 3      119                中島敦  1909-05-05  1942-12-04     男性        四谷区
# 4       96               夢野久作  1889-01-04  1936-03-11     男性        福岡市
# ...    ...                ...         ...         ...    ...        ...
# 1099  1239           ラングアンドルー  1844-03-31  1912-07-20    NaN        NaN
# 1100  1688  リヴィングストン・ジュニアヘンリー  1748-10-13  1828-02-29    NaN        NaN
# 1101   339            ルターマルチン  1483-11-10  1546-02-18    NaN        NaN
# 1102    29          レイモンドエリック         NaN         NaN    NaN        NaN
# 1103  1859   レ・ファニュジョゼフ・シェリダン  1814-08-28  1873-02-07    NaN        NaN
#
# [1104 rows x 6 columns]

# %%
df_combine[df_combine['deathDate_x'].isna()]
# Out:
#         id     author birthDate_x deathDate_x gender birthPlace
# 23    1128        文部省         NaN         NaN    NaN        NaN
# 49      52        紫式部         NaN         NaN    NaN        NaN
# 83    1529       作者不詳         NaN         NaN    NaN        NaN
# 131   1839      荒木光二郎         NaN         NaN    NaN        NaN
# 158   1528        日本国         NaN         NaN    NaN        NaN
# ...    ...        ...         ...         ...    ...        ...
# 1069   109        冬佳彰         NaN         NaN    NaN        NaN
# 1092    79        森野光         NaN         NaN    NaN        NaN
# 1094   198        山本洋  1956-00-00         NaN    NaN        NaN
# 1095   191       山本光夫  1959-00-00         NaN    NaN        NaN
# 1102    29  レイモンドエリック         NaN         NaN    NaN        NaN
#
# [88 rows x 6 columns]

# %%
df_combine.loc[1000:]
# Out:
#         id             author birthDate_x deathDate_x gender birthPlace
# 1000   108               小泉英政  1948-00-00         NaN     男性        NaN
# 1001  1756       コールデコットランドルフ  1846-03-22  1886-02-12    NaN        NaN
# 1002    16               小中千昭  1961-04-04         NaN     男性        東京都
# 1003  1241      ゴルドンエリザベス、アンナ  1851-00-00  1925-00-00    NaN        NaN
# 1004   151                西府章         NaN         NaN    NaN        NaN
# ...    ...                ...         ...         ...    ...        ...
# 1099  1239           ラングアンドルー  1844-03-31  1912-07-20    NaN        NaN
# 1100  1688  リヴィングストン・ジュニアヘンリー  1748-10-13  1828-02-29    NaN        NaN
# 1101   339            ルターマルチン  1483-11-10  1546-02-18    NaN        NaN
# 1102    29          レイモンドエリック         NaN         NaN    NaN        NaN
# 1103  1859   レ・ファニュジョゼフ・シェリダン  1814-08-28  1873-02-07    NaN        NaN
#
# [104 rows x 6 columns]

# %%
nulls(df_combine)
# Out:
#           cols  null_count  % null
# 0   birthPlace         615  55.707
# 1       gender         476  43.116
# 2  deathDate_x          88   7.971
# 3  birthDate_x          56   5.072
# 4       author           0   0.000
# 5           id           0   0.000

# %%
df_combine = df_combine.rename({'deathDate_x': 'deathDate', 'birthDate_x': 'birthDate'}, axis=1)

# %%
df_combine
# Out:
#         id             author   birthDate   deathDate gender birthPlace
# 0      148               夏目漱石  1867-02-09  1916-12-09     男性       喜久井町
# 1       81               宮沢賢治  1896-08-27  1933-09-21     男性      花巻川口町
# 2       35                太宰治  1909-06-19  1948-06-13     男性        金木町
# 3      119                中島敦  1909-05-05  1942-12-04     男性        四谷区
# 4       96               夢野久作  1889-01-04  1936-03-11     男性        福岡市
# ...    ...                ...         ...         ...    ...        ...
# 1099  1239           ラングアンドルー  1844-03-31  1912-07-20    NaN        NaN
# 1100  1688  リヴィングストン・ジュニアヘンリー  1748-10-13  1828-02-29    NaN        NaN
# 1101   339            ルターマルチン  1483-11-10  1546-02-18    NaN        NaN
# 1102    29          レイモンドエリック         NaN         NaN    NaN        NaN
# 1103  1859   レ・ファニュジョゼフ・シェリダン  1814-08-28  1873-02-07    NaN        NaN
#
# [1104 rows x 6 columns]

# %%
df_combine.loc[1102, ['birthDate', 'gender', 'birthPlace']] = ['1957-12-04', '男性', 'Boston']

# %%
df_combine.iloc[1102]
# Out:
# id                    29
# author         レイモンドエリック
# birthDate     1957-12-04
# deathDate            NaN
# gender                男性
# birthPlace        Boston
# Name: 1102, dtype: object

# %%
df_english = pd.read_excel('./data/aozora.xlsx','persons',usecols=['人物ID', '姓ローマ字', '名ローマ字'])

# %%
df_english
# Out:
#       人物ID            姓ローマ字            名ローマ字
# 0      148          Natsume           Soseki
# 1       81         Miyazawa            Kenji
# 2       35            Dazai            Osamu
# 3      119         Nakajima          Atsushi
# 4       96           Yumeno          Kyusaku
# ...    ...              ...              ...
# 1099  1239             Lang           Andrew
# 1100  1688  Livingston, Jr.            Henry
# 1101   339           Luther           Martin
# 1102    29          Raymond             Eric
# 1103  1859          Le Fanu  Joseph Sheridan
#
# [1104 rows x 3 columns]

# %%
df_english = df_english.rename({'人物ID': 'id', '姓ローマ字': 'last', '名ローマ字': 'first'}, axis=1)

df_english
# Out:
#         id             last            first
# 0      148          Natsume           Soseki
# 1       81         Miyazawa            Kenji
# 2       35            Dazai            Osamu
# 3      119         Nakajima          Atsushi
# 4       96           Yumeno          Kyusaku
# ...    ...              ...              ...
# 1099  1239             Lang           Andrew
# 1100  1688  Livingston, Jr.            Henry
# 1101   339           Luther           Martin
# 1102    29          Raymond             Eric
# 1103  1859          Le Fanu  Joseph Sheridan
#
# [1104 rows x 3 columns]

# %%
df = pd.merge(df_combine, df_english, how='left', on='id')

# %%
df
# Out:
#         id             author   birthDate   deathDate gender birthPlace  \
# 0      148               夏目漱石  1867-02-09  1916-12-09     男性       喜久井町
# 1       81               宮沢賢治  1896-08-27  1933-09-21     男性      花巻川口町
# 2       35                太宰治  1909-06-19  1948-06-13     男性        金木町
# 3      119                中島敦  1909-05-05  1942-12-04     男性        四谷区
# 4       96               夢野久作  1889-01-04  1936-03-11     男性        福岡市
# ...    ...                ...         ...         ...    ...        ...
# 1099  1239           ラングアンドルー  1844-03-31  1912-07-20    NaN        NaN
# 1100  1688  リヴィングストン・ジュニアヘンリー  1748-10-13  1828-02-29    NaN        NaN
# 1101   339            ルターマルチン  1483-11-10  1546-02-18    NaN        NaN
# 1102    29          レイモンドエリック  1957-12-04         NaN     男性     Boston
# 1103  1859   レ・ファニュジョゼフ・シェリダン  1814-08-28  1873-02-07    NaN        NaN
#
#                  last            first
# 0             Natsume           Soseki
# ...

# %%
df.to_csv('authors.csv', header=True, encoding='UTF-8')

# %%
df_null = df.isnull()

# %%
rows = df_null.any(axis=1)

# %%
rows
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1099     True
# 1100     True
# 1101     True
# 1102     True
# 1103     True
# Length: 1104, dtype: bool

# %%
df[rows]['id'].values
# Out:
# array([ 879,  296,  129, 1162,  914, 1128, 1566, 1235, 1092, 1091, 1124,
#          19,   94,  912,    9,  888,  363,  908, 1518, 1519,   52,  361,
#        1090,  258, 1347,  961, 1097,  924,  235, 1176, 1121, 1094,  269,
#         264, 1529,  140, 1048, 1120,  288, 1045,    5, 1296, 1134, 1044,
#        1028, 1029, 1025, 1465, 1839, 1257,  903,  226,  969, 1155, 1843,
#         279,  286, 1093, 1189, 1430, 1085, 1380,  207, 1528,  968,  351,
#        1099, 1159, 1421,  966, 1049, 1734,  989, 1477,  886,  981, 1277,
#         190, 1047, 1541, 1558, 1416, 1088, 1536,  967,  227,  224, 1156,
#        1364, 1065, 1217,  270,  748, 1331, 1568, 1648,  340,  368, 1733,
#        1125, 1263, 2034,  255, 1248, 1068,  905, 1789, 1417,  315, 1340,
#         289, 1329,  248, 1205,  810, 1407, 1539,  320, 1612, 1397, 1142,
#        1425,  268, 1399, 1325, 1486,   75, 1179, 1054,  740, 1195, 1372,
#        1702, 1190,  252,  488, 1193, 1192,  978, 1229,  304,   10,  712,
# ...

# %%
df.loc[rows, ['author', 'last', 'first']]
# Out:
#                  author             last            first
# 5                 芥川竜之介        Akutagawa        Ryunosuke
# 8                  福沢諭吉         Fukuzawa          Yukichi
# 11                  森鴎外             Mori             Ogai
# 13                  秋田滋            Akita          Shigeru
# 22           ディケンズチャールズ          Dickens          Charles
# ...                 ...              ...              ...
# 1099           ラングアンドルー             Lang           Andrew
# 1100  リヴィングストン・ジュニアヘンリー  Livingston, Jr.            Henry
# 1101            ルターマルチン           Luther           Martin
# 1102          レイモンドエリック          Raymond             Eric
# 1103   レ・ファニュジョゼフ・シェリダン          Le Fanu  Joseph Sheridan
#
# [634 rows x 3 columns]

# %%
len(df[rows]['id'])
# Out:
# 634

# %%
df.loc[5]
# Out:
# id                   879
# author             芥川竜之介
# birthDate     1892-03-01
# deathDate     1927-07-24
# gender               NaN
# birthPlace           NaN
# last           Akutagawa
# first          Ryunosuke
# Name: 5, dtype: object

# %% [markdown]
# ## After getting new data

# %%
df = pd.read_csv('authors.csv', index_col=0)

# %%
df
# Out:
#         id             author   birthDate   deathDate gender birthPlace  \
# 0      148               夏目漱石  1867-02-09  1916-12-09     男性       喜久井町
# 1       81               宮沢賢治  1896-08-27  1933-09-21     男性      花巻川口町
# 2       35                太宰治  1909-06-19  1948-06-13     男性        金木町
# 3      119                中島敦  1909-05-05  1942-12-04     男性        四谷区
# 4       96               夢野久作  1889-01-04  1936-03-11     男性        福岡市
# ...    ...                ...         ...         ...    ...        ...
# 1099  1239           ラングアンドルー  1844-03-31  1912-07-20    NaN        NaN
# 1100  1688  リヴィングストン・ジュニアヘンリー  1748-10-13  1828-02-29    NaN        NaN
# 1101   339            ルターマルチン  1483-11-10  1546-02-18    NaN        NaN
# 1102    29          レイモンドエリック  1957-12-04         NaN     男性     Boston
# 1103  1859   レ・ファニュジョゼフ・シェリダン  1814-08-28  1873-02-07    NaN        NaN
#
#                  last            first
# 0             Natsume           Soseki
# ...

# %%
df_append = pd.read_csv('doc.csv', index_col='index')

df_append
# Out:
#                    birthDate    birthPlace              deathDate gender
# index
# 5      +1892-03-01T00:00:00Z         Tokyo  +1927-07-24T00:00:00Z   male
# 8      +1835-01-10T00:00:00Z        Dōjima  +1901-02-03T00:00:00Z   male
# 11     +1862-02-17T00:00:00Z       Tsuwano  +1922-07-08T00:00:00Z   male
# 13                       NaN           NaN                    NaN    NaN
# 22     +1812-02-07T00:00:00Z      Landport  +1870-06-09T00:00:00Z   male
# ...                      ...           ...                    ...    ...
# 1099   +1844-03-31T00:00:00Z       Selkirk  +1912-07-20T00:00:00Z   male
# 1100   +1748-10-13T00:00:00Z  Poughkeepsie  +1828-02-29T00:00:00Z   male
# 1101   +1483-11-10T00:00:00Z      Eisleben  +1546-02-18T00:00:00Z   male
# 1102   +1957-12-04T00:00:00Z        Boston                    NaN   male
# 1103   +1814-08-28T00:00:00Z        Dublin  +1873-02-07T00:00:00Z   male
#
# [634 rows x 4 columns]

# %%
nulls(df)
# Out:
#          cols  null_count  % null
# 0  birthPlace         614  55.616
# 1      gender         475  43.025
# 2   deathDate          88   7.971
# 3   birthDate          55   4.982
# 4       first          31   2.808
# 5      author           0   0.000
# 6          id           0   0.000
# 7        last           0   0.000

# %%
# checking indices match

columns = df.loc[5].isna()

df.loc[5, columns]
# Out:
# gender        NaN
# birthPlace    NaN
# Name: 5, dtype: object

# %%
idx = df_append.index
idx
df.loc[idx]
# Out:
#          id             author   birthDate   deathDate gender birthPlace  \
# index
# 5       879              芥川竜之介  1892-03-01  1927-07-24    NaN        NaN
# 8       296               福沢諭吉  1835-01-10  1901-02-03    NaN        NaN
# 11      129                森鴎外  1862-02-17  1922-07-09    NaN        NaN
# 13     1162                秋田滋  1908-07-05  1943-10-15    NaN        NaN
# 22      914         ディケンズチャールズ  1812-02-07  1870-06-09    NaN        NaN
# ...     ...                ...         ...         ...    ...        ...
# 1099   1239           ラングアンドルー  1844-03-31  1912-07-20    NaN        NaN
# 1100   1688  リヴィングストン・ジュニアヘンリー  1748-10-13  1828-02-29    NaN        NaN
# 1101    339            ルターマルチン  1483-11-10  1546-02-18    NaN        NaN
# 1102     29          レイモンドエリック  1957-12-04         NaN     男性     Boston
# 1103   1859   レ・ファニュジョゼフ・シェリダン  1814-08-28  1873-02-07    NaN        NaN
#
#                   last            first
# index
# ...

# %%
def fill_na(df):
    idx = df_append.index
    for i, row in df.loc[idx].iterrows():
        columns = row.isna()
        cols = df.loc[i, columns].index.to_list()
        print(f'{cols}')
        if 'first' in cols:
            cols.remove('first')
            print(cols)
        if 'last' in cols:
            cols.remove('last')
            print(cols)
        df.loc[i, cols] = df_append.loc[i].loc[cols].values
       # print(df.loc[i])

# %%
fill_na(df)
# Out:
# []
# []
# []
# ['gender', 'birthPlace']
# []
# ['birthDate', 'deathDate', 'birthPlace', 'first']
# ['birthDate', 'deathDate', 'birthPlace']
# []
# []
# []
# []
# ['first']
# []
# []
# []
# []
# []
# []
# []
# []
# ['birthPlace']
# ['birthPlace']
# ['first']
# []
# []
# []
# []
# []
# []
# ['birthPlace']
# ['birthPlace']
# []
# []
# []
# []
# ['gender', 'birthPlace']
# []
# ['birthDate', 'deathDate', 'birthPlace', 'first']
# ['birthDate', 'deathDate', 'birthPlace']
# []
# []
# ['birthPlace']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['birthPlace']
# ['birthDate', 'deathDate', 'gender', 'birthPlace']
# []
# []
# []
# ['gender', 'birthPlace']
# []
# ['birthPlace']
# []
# []
# []
# []
# []
# []
# ['birthPlace']
# []
# ['birthDate', 'deathDate', 'birthPlace', 'first']
# ['birthDate', 'deathDate', 'birthPlace']
# ['gender', 'birthPlace']
# ['gender', 'birthPlace']
# ['birthDate', 'deathDate', 'birthPlace', 'first']
# ['birthDate', 'deathDate', 'birthPlace']
# []
# ['birthPlace']
# ...

# %%
df.shape
# Out:
# (1104, 8)

# %%
nulls(df)
# Out:
#          cols  null_count  % null
# 0  birthPlace         360  32.609
# 1      gender         181  16.395
# 2   deathDate          88   7.971
# 3   birthDate          54   4.891
# 4       first          31   2.808
# 5      author           0   0.000
# 6          id           0   0.000
# 7        last           0   0.000

# %%
nulls(df)
# Out:
#          cols  null_count  % null
# 0  birthPlace         361  32.699
# 1      gender         181  16.395
# 2   deathDate          87   7.880
# 3   birthDate          53   4.801
# 4       first          31   2.808
# 5      author           0   0.000
# 6          id           0   0.000
# 7        last           0   0.000

# %%
df[df['birthPlace'].isnull()].head(30)
# Out:
#        id    author   birthDate   deathDate  \
# 13   1162       秋田滋  1908-07-05  1943-10-15
# 23   1128       文部省         NaN         NaN
# 46   1518      太安万侶   somevalue  0723-08-15
# 47   1519      稗田阿礼  0700-01-01  0800-01-01
# 70   1097      下村湖人  1884-10-03  1955-04-20
# 72    924       永井隆  1908-02-03  1951-05-01
# 80    269      高神覚昇  1894-00-00  1948-00-00
# 83   1529      作者不詳         NaN         NaN
# 91   1120      須川邦彦  1880-00-00  1949-00-00
# 129  1465       東健而  1889-00-00  1933-00-00
# 131  1839     荒木光二郎         NaN         NaN
# 139   969      杉山萠円  1889-01-04  1936-03-11
# 142  1843  アレンリリー・Ｌ  1867-12-30  1952-02-14
# 156  1380      石川欣一  1895-03-17  1959-08-04
# 158  1528       日本国         NaN         NaN
# 161   968   かぐつちみどり  1889-01-04  1936-03-11
# 163   351      増田雅子  1880-05-06  1946-09-02
# 165  1099      ホーマー         NaN         NaN
# 168  1421      阿部次郎  1883-08-27  1959-10-20
# 172   966      海若藍平  1889-01-04  1936-03-11
# ...

# %%
df.loc[47, 'gender'] = 'unknown'

# %%
nulls(df)
# Out:
#          cols  null_count  % null
# 0  birthPlace         361  32.699
# 1      gender         181  16.395
# 2   deathDate          87   7.880
# 3   birthDate          53   4.801
# 4       first          31   2.808
# 5      author           0   0.000
# 6          id           0   0.000
# 7        last           0   0.000

# %%
df['birthDate'] = df['birthDate'].astype('str')

# %%
np.unique_values(df['birthDate'])
# Out:
# array(['+0973-00-00T00:00:00Z', '0700-01-01', '1008-00-00', '1048-00-00',
#        '1153-00-00', '1265-00-00', '1341-00-00', '1452-04-15',
#        '1483-11-10', '1533-02-28', '1546-00-00', '1596-00-00',
#        '1608-12-09', '1628-01-12', '1640-06-05', '1642-00-00',
#        '1659-00-00', '1667-11-30', '1694-00-00', '1695-00-00',
#        '1711-05-07', '1743-04-13', '1748-10-13', '1749-05-17',
#        '1749-08-28', '1757-11-28', '1761-09-13', '1765-08-02',
#        '1766-02-13', '1769-03-29', '1769-07-18', '1770-02-22', '1770-12',
#        '1771-00-00', '1772-04-19', '1772-11-14', '1776-01-24',
#        '1783-00-00', '1783-04-03', '1785-01-04', '1786-02-24',
#        '1796-10-24', '1797-01-10', '1797-08-30', '1799-05-20',
#        '1799-05-26', '1801-00-00', '1802-02-26', '1803-05-25',
#        '1804-07-04', '1805-04-02', '1807-04-20', '1809-01-19',
#        '1809-03-12', '1809-08-06', '1810-12-11', '1811-08-30',
#        '1812-02-07', '1812-05-07', '1813-03-15', '1814-08-28',
# ...

# %%
idx = df[df['birthDate'] == 'nan'].index

df.loc[idx, 'birthDate']
# Out:
# Series([], Name: birthDate, dtype: object)

# %%
df[df['birthDate'] == 'somevalue'] = None

# %%
df.loc[640, ['birthDate', 'deathDate', 'gender', 'birthPlace']] = [None, None, 'female', 'Greece']

# %%
df.loc[640]
# Out:
# id              1713
# author          サッフォ
# birthDate       None
# deathDate       None
# gender        female
# birthPlace    Greece
# last          Sappho
# first            NaN
# Name: 640, dtype: object

# %%
df.to_csv('authors2.csv', encoding='UTF-8',  header=True, index=False)

# %%
df.loc[0]
# Out:
# id                 148.0
# author              夏目漱石
# birthDate     1867-02-09
# deathDate     1916-12-09
# gender                男性
# birthPlace          喜久井町
# last             Natsume
# first             Soseki
# Name: 0, dtype: object

# %%
df['gender'] = df['gender'].map({'男性': 'male', '女性': 'female'})

# %%
np.unique_counts(df['gender'].astype(str))
# Out:
# UniqueCountsResult(values=array(['female', 'male', 'nan'], dtype=object), counts=array([ 56, 571, 477]))

# %%
df['id'] = df['id'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[264], line 1
# ----> 1 df['id'] = df['id'].astype('int')
#
# File d:\PythonDevelopment\jap_lit\env\Lib\site-packages\pandas\core\generic.py:6662, in NDFrame.astype(self, dtype, copy, errors)
#    6656     results = [
#    6657         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6658     ]
#    6660 else:
#    6661     # else, only a single dtype is given
# -> 6662     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6663     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6664     return res.__finalize__(self, method="astype")
#
# File d:\PythonDevelopment\jap_lit\env\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# ...

# %%
df.drop(index=46)
# Out:
#           id             author   birthDate   deathDate gender    birthPlace  \
# 0      148.0               夏目漱石  1867-02-09  1916-12-09   male          喜久井町
# 1       81.0               宮沢賢治  1896-08-27  1933-09-21   male         花巻川口町
# 2       35.0                太宰治  1909-06-19  1948-06-13   male           金木町
# 3      119.0                中島敦  1909-05-05  1942-12-04   male           四谷区
# 4       96.0               夢野久作  1889-01-04  1936-03-11   male           福岡市
# ...      ...                ...         ...         ...    ...           ...
# 1099  1239.0           ラングアンドルー  1844-03-31  1912-07-20    NaN       Selkirk
# 1100  1688.0  リヴィングストン・ジュニアヘンリー  1748-10-13  1828-02-29    NaN  Poughkeepsie
# 1101   339.0            ルターマルチン  1483-11-10  1546-02-18    NaN      Eisleben
# 1102    29.0          レイモンドエリック  1957-12-04         NaN   male        Boston
# 1103  1859.0   レ・ファニュジョゼフ・シェリダン  1814-08-28  1873-02-07    NaN        Dublin
#
#                  last            first
# ...

# %%
#46,somevalue,,+0723-08-15T00:00:00Z,maledd

# %%
df
# Out:
#         id             author   birthDate   deathDate gender    birthPlace  \
# 0      148               夏目漱石  1867-02-09  1916-12-09     男性          喜久井町
# 1       81               宮沢賢治  1896-08-27  1933-09-21     男性         花巻川口町
# 2       35                太宰治  1909-06-19  1948-06-13     男性           金木町
# 3      119                中島敦  1909-05-05  1942-12-04     男性           四谷区
# 4       96               夢野久作  1889-01-04  1936-03-11     男性           福岡市
# ...    ...                ...         ...         ...    ...           ...
# 1099  1239           ラングアンドルー  1844-03-31  1912-07-20   male       Selkirk
# 1100  1688  リヴィングストン・ジュニアヘンリー  1748-10-13  1828-02-29   male  Poughkeepsie
# 1101   339            ルターマルチン  1483-11-10  1546-02-18   male      Eisleben
# 1102    29          レイモンドエリック  1957-12-04         NaN     男性        Boston
# 1103  1859   レ・ファニュジョゼフ・シェリダン  1814-08-28  1873-02-07   male        Dublin
#
#                  last            first
# ...

# %%
df['gender'] = df['gender'].map({'男性': 'male', '女性': 'female'})

# %%
nulls(df)
# Out:
#          cols  null_count  % null
# 0  birthPlace         360  32.609
# 1      gender         181  16.395
# 2   deathDate          88   7.971
# 3   birthDate          54   4.891
# 4       first          31   2.808
# 5      author           0   0.000
# 6          id           0   0.000
# 7        last           0   0.000

# %%
np.unique_values(df['gender'].astype(str))
# Out:
# array(['female', 'male', 'nan', 'unknown'], dtype=object)

# %%
np.unique_values(df['deathDate'].astype(str))
# Out:
# array(['+1014-00-00T00:00:00Z', '0723-08-15', '0800-01-01', '1060-01-01',
#        '1131-00-00', '1216-00-00', '1321-00-00', '1427-00-00',
#        '1519-05-02', '1546-02-18', '1592-09-13', '1616-00-00',
#        '1650-00-00', '1674-11-08', '1693-09-09', '1703-05-16',
#        '1715-02-25', '1731-04-26', '1745-10-19', '1755-00-00',
#        '1776-08-25', '1778-00-00', '1816-10-27', '1822-06-25',
#        '1823-01-26', '1823-09-11', '1824-00-00', '1826-07-04',
#        '1827-03-26', '1827-8-12', '1828-02-29', '1832-03-22',
#        '1834-12-29', '1835-12-05', '1837-01-17', '1838-06-28',
#        '1841-00-00', '1841-04-29', '1842-06-23', '1848-05-07',
#        '1848-05-25', '1849-10-07', '1850-08--18', '1851-02-01',
#        '1852-02-21', '1855-03-31', '1857-05-02', '1858-06-16',
#        '1858-10-30', '1859-10-19', '1859-11-21', '1859-11-28',
#        '1859-12-16', '1862-05-06', '1863-09-20', '1864-05-19',
#        '1867-08-31', '1867-12-10', '1870-06-09', '1872-10-23',
# ...

# %%
df.loc[46, 'birthDate'] = np.nan

# %%
df.loc[949, ['birthDate', 'deathDate']] = ['1861-08-25', '1939-08-31']

# %%
df[df['deathDate'] == '前347-00-00']
# Out:
#        id author   birthDate   deathDate gender birthPlace   last first
# 1070  915   プラトン  前427-00-00  前347-00-00   male     Athens  Plato   NaN

# %%
df.loc[1070, ['birthDate', 'deathDate']] = ['-0427-00-00', '-0347-00-00']

# %%
df.loc[49, 'deathDate'] = '1014-00-00'

# %%
np.unique_values(df['birthPlace'].astype(str))
# Out:
# array(['10th arrondissement of Paris', '14th arrondissement of Paris',
#        '2nd arrondissement of Lyon', 'Agano', 'Agrigento', 'Altoona',
#        'Anchiano', 'Athens', 'Bagni di Lucca', 'Barmen', 'Baxi Jun',
#        'Bazoches-au-Houlme', 'Berkeley', 'Berlin', 'Besançon',
#        'Bloomington', 'Bond Head', 'Bonn', 'Boston', 'Bromley',
#        'Brooklyn', 'Budapest', 'Burg Hülshoff', 'Bury St Edmunds',
#        'Bückeburg', 'Castlerea', 'Ceva', 'Charleville', 'Chaville',
#        'Cheapside', 'Chester', 'Chiba Prefecture', 'Chikuzen Province',
#        'Chittenango', 'Châlons-du-Maine', 'Clamecy', 'Cologne',
#        'Daresbury', 'Descartes', 'Dieppe', 'Dobroslavivka', 'Donington',
#        'Dublin', 'Dōjima', 'Edinburgh', 'Edo', 'Eisleben', 'Florence',
#        'Frankfurt', 'Fukuoka', 'Fukuoka Prefecture', 'Fukusaki',
#        'Fushimi-ku', 'Germantown', 'Gladhammar church parish', 'Greece',
#        'Greensboro', 'Greenwich', 'Hanau', 'Hangzhou', 'Heian-kyō',
# ...

# %%
np.unique_values(df['gender'].astype(str))
# Out:
# array(['female', 'male', 'nan', 'unknown'], dtype=object)

# %%
df.to_csv('authors2.csv', index=False, header=True, encoding='UTF-8')

# %%
b = pd.read_excel('./data/aozora.xlsx', 'books')

# %%
b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16599 entries, 0 to 16598
# Data columns (total 60 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   作品ID                 16599 non-null  int64
#  1   作品名                  16599 non-null  object
#  2   作品名読み                16599 non-null  object
#  3   ソート用読み               16592 non-null  object
#  4   副題                   2699 non-null   object
#  5   副題読み                 2694 non-null   object
#  6   原題                   822 non-null    object
#  7   初出                   9387 non-null   object
#  8   分類番号                 16596 non-null  object
#  9   文字遣い種別               16599 non-null  object
#  10  作品著作権フラグ             16599 non-null  object
#  11  公開日                  16599 non-null  datetime64[ns]
#  12  最終更新日                16599 non-null  datetime64[ns]
#  13  図書カードURL             16599 non-null  object
#  14  人物ID                 16599 non-null  int64
# ...

# %%
nulls(b)
# Out:
#                    cols  null_count  % null
# 0            底本の親本出版社名2       16564  99.789
# 1               底本の親本名2       16557  99.747
# 2           底本の親本初版発行年2       16557  99.747
# 3             校正に使用した版2       16550  99.705
# 4             入力に使用した版2       16526  99.560
# 5              底本初版発行年2       16508  99.452
# 6               底本出版社名2       16506  99.440
# 7                  底本名2       16503  99.422
# 8                    原題       15777  95.048
# 9                  副題読み       13905  83.770
# 10                   副題       13900  83.740
# 11           底本の親本出版社名1        9971  60.070
# 12          底本の親本初版発行年1        9090  54.762
# 13              底本の親本名1        8990  54.160
# 14                   初出        7212  43.448
# 15            校正に使用した版1        4105  24.730
# 16            入力に使用した版1        1228   7.398
# 17                   姓名         818   4.928
# 18             底本初版発行年1         496   2.988
# 19                  校正者         486   2.928
# ...

# %%
b = pd.read_excel('./data/aozora.xlsx', 'books', usecols=['作品ID', '作品名', '分類番号', '文字遣い種別', '人物ID', '役割フラグ', '底本初版発行年1', '底本出版社名1', '文字数', 'カテゴリ', 'XHTML/HTMLファイルURL', '図書カードURL'])

# %%
nulls(b)
# Out:
#                  cols  null_count  % null
# 0            底本初版発行年1         496   2.988
# 1             底本出版社名1         472   2.844
# 2                カテゴリ         246   1.482
# 3                 文字数         238   1.434
# 4   XHTML/HTMLファイルURL          36   0.217
# 5                分類番号           3   0.018
# 6                作品ID           0   0.000
# 7                 作品名           0   0.000
# 8              文字遣い種別           0   0.000
# 9               役割フラグ           0   0.000
# 10           図書カードURL           0   0.000
# 11               人物ID           0   0.000

# %%
idx = b[b['底本出版社名1'].isnull()].index
np.unique_values(b.loc[idx, ['底本初版発行年1']].astype(str))
# Out:
# array(['1893（明治26）年12月', '1920（大正9）年4月号', '1942（昭和17）年2月', 'nan'],
#       dtype=object)

# %%
# Out:
# <bound method hist_series of 0        184158.0
# 1           395.0
# 2         10344.0
# 3        368124.0
# 4          6986.0
#            ...
# 16594         NaN
# 16595         NaN
# 16596      6029.0
# 16597    445193.0
# 16598      5537.0
# Name: 文字数, Length: 16599, dtype: float64>

# %%
df = pd.read_excel('./data/Book1.xlsx', sheet_name='combined')

df
# Out:
#         date         WPI
# 0    1887.01   55.555556
# 1    1887.02   56.666667
# 2    1887.03   55.555556
# 3    1887.04   55.555556
# 4    1887.05   55.000000
# ..       ...         ...
# 535  1931.08  151.800000
# 536  1931.09  149.600000
# 537  1931.10  146.900000
# 538  1931.11  147.000000
# 539  1931.12  151.000000
#
# [540 rows x 2 columns]

# %%
df['date'] = df['date'].astype(str)

np.unique_values(df['date'])
# Out:
# array(['1887.01', '1887.02', '1887.03', '1887.04', '1887.05', '1887.06',
#        '1887.07', '1887.08', '1887.09', '1887.1', '1887.11', '1887.12',
#        '1888.01', '1888.02', '1888.03', '1888.04', '1888.05', '1888.06',
#        '1888.07', '1888.08', '1888.09', '1888.1', '1888.11', '1888.12',
#        '1889.01', '1889.02', '1889.03', '1889.04', '1889.05', '1889.06',
#        '1889.07', '1889.08', '1889.09', '1889.1', '1889.11', '1889.12',
#        '1890.01', '1890.02', '1890.03', '1890.04', '1890.05', '1890.06',
#        '1890.07', '1890.08', '1890.09', '1890.1', '1890.11', '1890.12',
#        '1891.01', '1891.02', '1891.03', '1891.04', '1891.05', '1891.06',
#        '1891.07', '1891.08', '1891.09', '1891.1', '1891.11', '1891.12',
#        '1892.01', '1892.02', '1892.03', '1892.04', '1892.05', '1892.06',
#        '1892.07', '1892.08', '1892.09', '1892.1', '1892.11', '1892.12',
#        '1893.01', '1893.02', '1893.03', '1893.04', '1893.05', '1893.06',
# ...

# %%
def getYear(row):
    return row[0: row.find('/')]

# %%
df.head()
# Out:
#       date        WPI  year
# 0  1887.01  55.555556  1887
# 1  1887.02  56.666667  1887
# 2  1887.03  55.555556  1887
# 3  1887.04  55.555556  1887
# 4  1887.05  55.000000  1887

# %%
grouped = df.groupby('year')['WPI'].mean().reset_index()

# %%
grouped.head()
# Out:
#    year        WPI
# 0  1887  56.898148
# 1  1888  59.398148
# 2  1889  62.129630
# 3  1890  65.092593
# 4  1891  60.462963

# %%
add = pd.read_excel('./data/Book1.xlsx', sheet_name='new')

add
# Out:
#         year     WPI
# 0    1931.01    82.6
# 1    1931.02    83.2
# 2    1931.03    83.9
# 3    1931.04    82.3
# 4    1931.05    78.9
# ..       ...     ...
# 187  1946.08  1832.0
# 188  1946.09  2006.7
# 189  1946.10  2003.5
# 190  1946.11  2225.5
# 191  1946.12  2330.3
#
# [192 rows x 2 columns]

# %%
add['date'] = add['year'].astype(str)
add['year'] = add['date'].apply(getYear)

add.head()
# Out:
#    year   WPI     date
# 0  1931  82.6  1931.01
# 1  1931  83.2  1931.02
# 2  1931  83.9  1931.03
# 3  1931  82.3  1931.04
# 4  1931  78.9  1931.05

# %%
add_grouped = add.groupby('year')['WPI'].mean().reset_index()

add_grouped.head()
# Out:
#    year         WPI
# 0  1931   78.741667
# 1  1932   87.300000
# 2  1933  100.008333
# 3  1934  101.950000
# 4  1935  104.591667

# %%
grouped[grouped['year'] == '1931']
# Out:
#     year         WPI
# 44  1931  153.041667

# %%
wpi1 = grouped.loc[grouped['year'] == '1931', 'WPI'].values[0]
wpi2 = add_grouped.loc[add_grouped['year'] == '1931', 'WPI'].values[0]

# %%
wpi1, wpi2
# Out:
# (np.float64(153.04166666666666), np.float64(78.74166666666666))

# %%
grouped['rebased_1931'] = grouped['WPI'] / wpi1 * 100
add_grouped['rebased_1931'] = add_grouped['WPI'] / wpi2 * 100

# %%
grouped[grouped['year'].isin(['1930', '1931', '1932'])]
# Out:
#     year         WPI  rebased_1931
# 43  1930  180.975000     118.25211
# 44  1931  153.041667     100.00000

# %%
add_grouped.head(5)
# Out:
#    year         WPI  rebased_1931
# 0  1931   78.741667    100.000000
# 1  1932   87.300000    110.868875
# 2  1933  100.008333    127.008149
# 3  1934  101.950000    129.474018
# 4  1935  104.591667    132.828871

# %%
merged = pd.merge(grouped[['year', 'rebased_1931']], add_grouped[['year', 'rebased_1931']], on='year', how='outer')

# %%
merged['WPI'] = merged['rebased_1931_x'].combine_first(merged['rebased_1931_y'])

# %%
merged = merged[['year','WPI']]

merged
# Out:
#     year          WPI
# 0   1887    37.178207
# 1   1888    38.811749
# 2   1889    40.596545
# 3   1890    42.532595
# 4   1891    39.507517
# 5   1892    41.655323
# 6   1893    43.288865
# 7   1894    45.890432
# 8   1895    48.915510
# 9   1896    52.757359
# 10  1897    58.293251
# 11  1898    61.772091
# 12  1899    62.014097
# 13  1900    66.312430
# 14  1901    63.025683
# 15  1902    63.321536
# 16  1903    67.367275
# 17  1904    70.819494
# 18  1905    76.035938
# 19  1906    78.252110
# 20  1907    84.475905
# 21  1908    81.388511
# 22  1909    77.604138
# 23  1910    78.611489
# 24  1911    81.475633
# 25  1912    86.289137
# 26  1913    86.452491
# 27  1914    82.537435
# 28  1915    83.484890
# 29  1916   101.007351
# 30  1917   127.095018
# 31  1918   166.474272
# 32  1919   203.942282
# 33  1920   224.247209
# 34  1921   173.204465
# 35  1922   169.229513
# 36  1923   172.142663
# 37  1924   178.513477
# 38  1925   174.358835
# 39  1926   154.636537
# ...

# %%
a = [104.6,
99.5,
97.8,
96.9,
98.7,
101.2,
100.8,
100.5,
102.3,
101,
99.7,
97.1]

# %%
a = np.array(a)
a.prod()**(1.0/len(a))
# Out:
# np.float64(99.98566843014156)

# %%
new = pd.read_excel('./data/Book1.xlsx', sheet_name='new')

new
# Out:
#     Year  Wholesale
# 0   1946       16.3
# 1   1947       48.2
# 2   1948      127.9
# 3   1949      208.8
# 4   1950      246.8
# 5   1951      342.5
# 6   1952      349.2
# 7   1953      351.6
# 8   1954      349.2
# 9   1955      342.9
# 10  1956      357.9

# %%
new = new.rename(columns={new.columns[1]: 'WPI'})

# %%
new
# Out:
#     year     WPI
# 0   1946    16.3
# 1   1947    48.2
# 2   1948   127.9
# 3   1949   208.8
# 4   1950   246.8
# 5   1951   342.5
# 6   1952   349.2
# 7   1953   351.6
# 8   1954   349.2
# 9   1955   342.9
# 10  1956   357.9

# %%
new['year'] = new['year'].astype(str)
new['WPI'] = new['WPI'].astype(float)

new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    11 non-null     object
#  1   WPI     11 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 308.0+ bytes

# %%
wpi1 = merged.loc[merged['year'] == '1946', 'WPI'].values[0]
wpi2 = new.loc[new['year'] == '1946', 'WPI'].values[0]

merged['rebased_1946'] = merged['WPI'] / wpi1 * 100
new['rebased_1946'] = new['WPI'] / wpi2 * 100

# %%
df['year'] = df['year'].astype(str)

# %%
merged = pd.merge(df[['year', 'rebased_1946']], new[['year', 'rebased_1946']], on='year', how='outer')
merged['WPI'] = merged['rebased_1946_x'].combine_first(merged['rebased_1946_y'])

# %%
merged
# Out:
#     year  rebased_1946_x  rebased_1946_y         WPI
# 0   1887        1.830997        1.830997    1.830997
# 1   1888        1.911447        1.911447    1.911447
# 2   1889        1.999347        1.999347    1.999347
# 3   1890        2.094696        2.094696    2.094696
# 4   1891        1.945713        1.945713    1.945713
# 5   1892        2.051491        2.051491    2.051491
# 6   1893        2.131942        2.131942    2.131942
# 7   1894        2.260067        2.260067    2.260067
# 8   1895        2.409050        2.409050    2.409050
# 9   1896        2.598257        2.598257    2.598257
# 10  1897        2.870896        2.870896    2.870896
# 11  1898        3.042226        3.042226    3.042226
# 12  1899        3.054144        3.054144    3.054144
# 13  1900        3.265834        3.265834    3.265834
# 14  1901        3.103964        3.103964    3.103964
# 15  1902        3.118535        3.118535    3.118535
# 16  1903        3.317784        3.317784    3.317784
# ...

# %%
merged= merged[['year','WPI']]

# %%
merged['WPI'] = np.round(merged['WPI'], 2)
# Out:
# C:\Users\Jaden\AppData\Local\Temp\ipykernel_9508\2110325162.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged['WPI'] = np.round(merged['WPI'], 2)

# %%
merged['year'] = merged['year'].astype(float)

merged[merged['year'] > 1940]
# Out:
#       year          WPI
# 54  1941.0    11.471847
# 55  1942.0    12.334972
# 56  1943.0    13.077697
# 57  1944.0    14.570444
# 58  1945.0    20.688936
# 59  1946.0   100.000000
# 60  1947.0   295.705521
# 61  1948.0   784.662577
# 62  1949.0  1280.981595
# 63  1950.0  1514.110429
# 64  1951.0  2101.226994
# 65  1952.0  2142.331288
# 66  1953.0  2157.055215
# 67  1954.0  2142.331288
# 68  1955.0  2103.680982
# 69  1956.0  2195.705521

# %%
merged
# Out:
#       year          WPI
# 0   1887.0     1.830997
# 1   1888.0     1.911447
# 2   1889.0     1.999347
# 3   1890.0     2.094696
# 4   1891.0     1.945713
# ..     ...          ...
# 65  1952.0  2142.331288
# 66  1953.0  2157.055215
# 67  1954.0  2142.331288
# 68  1955.0  2103.680982
# 69  1956.0  2195.705521
#
# [70 rows x 2 columns]

# %%
new = pd.read_excel('./data/Book1.xlsx', sheet_name='new')

new
# Out:
#         Year    WPI
# 0   1957.010  106.7
# 1   1957.020  106.6
# 2   1957.030  106.6
# 3   1957.040  106.5
# 4   1957.050  106.0
# 5   1957.060  105.6
# 6   1957.070  104.6
# 7   1957.080  104.0
# 8   1957.090  104.2
# 9   1957.100  104.6
# 10  1957.110  104.1
# 11  1957.120  103.0
# 12  1958.010  101.6
# 13  1958.020  100.3
# 14  1958.030   99.8
# 15  1958.040   99.6
# 16  1958.050   98.9
# 17  1958.060   98.0
# 18  1958.070   97.6
# 19  1958.080   97.3
# 20  1958.090   96.9
# 21  1958.100   96.8
# 22  1958.110   97.3
# 23  1958.120   97.5
# 24  1959.012   97.8
# 25  1959.020   98.3
# 26  1959.028   98.6
# 27  1959.036   98.8
# 28  1959.052   98.7
# 29  1959.060   98.5
# 30  1959.068   98.6
# 31  1959.084   99.7
# 32  1959.092  100.1
# 33  1959.100  101.0
# 34  1959.108  101.8
# 35  1959.116  101.6
# 36  1960.010  101.5
# 37  1960.020  101.1
# 38  1960.030  101.0
# 39  1960.040  100.9
# 40  1960.050  100.8
# 41  1960.060  100.7
# 42  1960.070  100.6
# 43  1960.080  101.0
# ...

# %%
new['Year'] = np.round(new['Year'], 2)

# %%
new['date'] = new['Year'].astype(str)
new['Year'] = new['date'].apply(getYear)

new.head()
# Out:
#    Year    WPI     date
# 0  1957  106.7  1957.01
# 1  1957  106.6  1957.02
# 2  1957  106.6  1957.03
# 3  1957  106.5  1957.04
# 4  1957  106.0  1957.05

# %%
new = new.groupby('Year')['WPI'].mean().reset_index()

# %%
new.head()
# Out:
#    Year         WPI
# 0  1957  105.208333
# 1  1958   98.466667
# 2  1959   99.458333
# 3  1960  101.341667

# %%
def reconcile(year, df1, df2):
    wpi1 = df1.loc[df1['year'] == year, 'WPI'].values[0]
    wpi2 = df2.loc[df2['Year'] == year, 'WPI'].values[0]
    df1['rebased_1946'] = df1['WPI'] / wpi1 * 100
    df2['rebased_1946'] = df2['WPI'] / wpi2 * 100

# %%
a['year'] = a['year'].astype(str)
b = b.rename(columns={'Year': 'year'})

# %%
a.loc[a['year'] == '1952.0', 'WPI']
# Out:
# Series([], Name: WPI, dtype: float64)

# %%
a[a.columns[0]] = a[a.columns[0]].astype(str)

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    70 non-null     float64
#  1   WPI     70 non-null     float64
# dtypes: float64(2)
# memory usage: 1.2 KB

# %%
a['year'] = a['year'].apply(lambda x: x[0: x.find('.')])

# %%
a.loc[a['year'] == '1952', 'WPI']
# Out:
# 65    2142.331288
# Name: WPI, dtype: float64

# %%
b = b.rename(columns={'Year': 'year'})

# %%
a['year'] = a['year'].astype(int)
b['year'] = b['year'].astype(int)

# %%
wpi1 = a.loc[a['year'] == 1952, 'WPI'].values[0]

# %%
a['rebased_1952'] = a['WPI'] / wpi1 * 100

# %%
b['rebased_1952']  =b['WPI']

# %%
merged = pd.merge(a[['year', 'rebased_1952']], b[['year', 'rebased_1952']], on='year', how='outer')
merged['WPI'] = merged['rebased_1952_x'].combine_first(merged['rebased_1952_y'])

# %%
merged = merged[['year', 'WPI']]

# %%
merged
# Out:
#     year         WPI
# 0   1887    0.085468
# 1   1888    0.089223
# 2   1889    0.093326
# 3   1890    0.097776
# 4   1891    0.090822
# ..   ...         ...
# 69  1956  102.491409
# 70  1957  105.208333
# 71  1958   98.466667
# 72  1959   99.458333
# 73  1960  101.341667
#
# [74 rows x 2 columns]

# %%
new = pd.read_excel('./data/Book1.xlsx', sheet_name='new')

new
# Out:
#         Year   WPI
# 0    1960/01  47.9
# 1    1960/02  47.9
# 2    1960/03  47.8
# 3    1960/04  47.7
# 4    1960/05  47.6
# ..       ...   ...
# 510  2002/07  94.4
# 511  2002/08  94.3
# 512  2002/09  94.3
# 513  2002/10  94.2
# 514  2002/11  94.3
#
# [515 rows x 2 columns]

# %%
new = new.rename(columns={'Year': 'year'})

new['year'] = new['year'].apply(getYear)

# %%
new = new.groupby('year')['WPI'].mean().reset_index()

new
# Out:
#     year         WPI
# 0   1960   47.650000
# 1   1961   48.175000
# 2   1962   47.408333
# 3   1963   48.125000
# 4   1964   48.158333
# 5   1965   48.683333
# 6   1966   50.016667
# 7   1967   51.191667
# 8   1968   51.650000
# 9   1969   52.658333
# 10  1970   54.491667
# 11  1971   54.033333
# 12  1972   54.900000
# 13  1973   63.508333
# 14  1974   81.000000
# 15  1975   83.275000
# 16  1976   87.833333
# 17  1977   90.775000
# 18  1978   90.325000
# 19  1979   94.825000
# 20  1980  109.008333
# 21  1981  110.491667
# 22  1982  111.008333
# 23  1983  110.291667
# 24  1984  110.391667
# 25  1985  109.541667
# 26  1986  104.416667
# 27  1987  101.133333
# 28  1988  100.550000
# 29  1989  102.491667
# 30  1990  104.050000
# 31  1991  105.066667
# 32  1992  104.166667
# 33  1993  102.550000
# 34  1994  100.825000
# 35  1995   99.983333
# 36  1996   98.350000
# 37  1997   99.025000
# 38  1998   97.475000
# 39  1999   96.050000
# 40  2000   96.133333
# 41  2001   95.266667
# ...

# %%
new['year'] = new['year'].astype(int)

# %%
reconcile(1960, new, merged)
# Out:
# C:\Users\Jaden\AppData\Local\Temp\ipykernel_9508\699785757.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['rebased_1946'] = df2['WPI'] / wpi2 * 100

# %%
new
# Out:
#     year         WPI  rebased_1946
# 0   1960   47.650000    100.000000
# 1   1961   48.175000    101.101784
# 2   1962   47.408333     99.492830
# 3   1963   48.125000    100.996852
# 4   1964   48.158333    101.066807
# 5   1965   48.683333    102.168590
# 6   1966   50.016667    104.966772
# 7   1967   51.191667    107.432669
# 8   1968   51.650000    108.394544
# 9   1969   52.658333    110.510668
# 10  1970   54.491667    114.358167
# 11  1971   54.033333    113.396292
# 12  1972   54.900000    115.215110
# 13  1973   63.508333    133.280867
# 14  1974   81.000000    169.989507
# 15  1975   83.275000    174.763903
# 16  1976   87.833333    184.330185
# 17  1977   90.775000    190.503673
# 18  1978   90.325000    189.559286
# 19  1979   94.825000    199.003148
# 20  1980  109.008333    228.768800
# 21  1981  110.491667    231.881777
# 22  1982  111.008333    232.966072
# 23  1983  110.291667    231.462050
# 24  1984  110.391667    231.671913
# 25  1985  109.541667    229.888073
# ...

# %%
merged
# Out:
#     year         WPI  rebased_1946
# 0   1887    0.085468      0.084336
# 1   1888    0.089223      0.088042
# 2   1889    0.093326      0.092090
# 3   1890    0.097776      0.096482
# 4   1891    0.090822      0.089620
# ..   ...         ...           ...
# 69  1956  102.491409    101.134521
# 70  1957  105.208333    103.815476
# 71  1958   98.466667     97.163062
# 72  1959   99.458333     98.141600
# 73  1960  101.341667    100.000000
#
# [74 rows x 3 columns]

# %%
merged = pd.merge(merged[['year', 'rebased_1946']], new[['year', 'rebased_1946']], on='year', how='outer')
merged['WPI'] = merged['rebased_1946_x'].combine_first(merged['rebased_1946_y'])

# %%
merged = merged[['year', 'WPI']]

# %%
merged
# Out:
#      year         WPI
# 0    1887    0.084336
# 1    1888    0.088042
# 2    1889    0.092090
# 3    1890    0.096482
# 4    1891    0.089620
# ..    ...         ...
# 111  1998  204.564533
# 112  1999  201.573977
# 113  2000  201.748863
# 114  2001  199.930045
# 115  2002  197.977678
#
# [116 rows x 2 columns]

# %%
wpi1 = merged.loc[merged['year'] == 1945, 'WPI'].values[0]
merged['rebased_1914'] = merged['WPI'] / wpi1 * 100
# Out:
# C:\Users\Jaden\AppData\Local\Temp\ipykernel_9508\83433118.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged['rebased_1914'] = merged['WPI'] / wpi1 * 100

# %%
merged['rebased_1914'] =  np.round(merged['rebased_1914'],2)
# Out:
# C:\Users\Jaden\AppData\Local\Temp\ipykernel_9508\3956036652.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged['rebased_1914'] =  np.round(merged['rebased_1914'],2)

# %%
df = merged.copy()

df['WPI'] = df['rebased_1914']

# %%
df = df[['year', 'WPI']]

# %%
df
# Out:
#      year       WPI
# 0    1887      8.85
# 1    1888      9.24
# 2    1889      9.66
# 3    1890     10.12
# 4    1891      9.40
# ..    ...       ...
# 111  1998  21466.78
# 112  1999  21152.95
# 113  2000  21171.30
# 114  2001  20980.44
# 115  2002  20775.56
#
# [116 rows x 2 columns]

# %%
df.to_csv('./data/WPI.csv', encoding='UTF-8', header=True, index=False)
